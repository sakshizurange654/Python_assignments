# %%
#1. Write a Python script to sort (ascending and descending) a dictionary by value.

# %%
dict1 = {'d':4,
        'c':3,
        'a':1,
        'b':2}
dict_asc = dict(sorted(dict1.items()))
print(dict_asc)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
dict1 = {'d':4,
        'c':3,
        'a':1,
        'b':2}
dict_asc = dict(sorted(dict1.items(), reverse=True))
print(dict_asc)
# Out:
# {'d': 4, 'c': 3, 'b': 2, 'a': 1}

# %%
"""Write a Python script to add a key to a dictionary. 
Sample Dictionary : {0: 10, 1: 20}
Expected Result : {0: 10, 1: 20, 2: 30}"""

sample = {0: 10, 1: 20}
sample[2] = 30
print(sample)
# Out:
# {0: 10, 1: 20, 2: 30}

# %%
'''3. Write a Python script to concatenate the following dictionaries to create a new one. 
Sample Dictionary : 
dic1={1:10, 2:20} 
dic2={3:30, 4:40} 
dic3={5:50,6:60}
Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}'''


dic1={1:10, 2:20} 
dic2={3:30, 4:40} 
dic3={5:50,6:60}

result={}

result.update(dic1)
result.update(dic2)
result.update(dic3)
print(result)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
for i in (dic1,dic2,dic3):
    result.update(i)
print(result)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
#4. Write a Python script to check whether a given key already exists in a dictionary.

# %%
data = {"name": "sakshi",
       "age": 21,
       "course": "computer",
       }
a = input("enter your key: ")
if a in  data:
    print("its exist in a dictionary")
else:
    print("it does not exist in dictionary")
# Out:
# enter your key: domain
# it does not exist in dictionary

# %%
#5. Write a Python program to iterate over dictionaries using for loops.

# %%
print("keys: ")
for i in data:
    print(i)

print("\nValues: ")
for j in data.values():
    print(j)
# Out:
# keys:
# name
# age
# course
#
# Values:
# sakshi
# 21
# computer

# %%
"""6. Write a Python script to generate and print a dictionary that contains a number (between 1 and n) in the form (x, x*x). 
Sample Dictionary ( n = 5) : 
Expected Output : {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}"""



a = int(input("enter the number: "))
result = {}

for i in range(1, a+1):
    result[i] = i*i
print(result)
# Out:
# enter the number: 5
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
"""7. Write a Python script to print a dictionary where the keys are numbers between 1 and 15 (both included) and the values are the square of the keys. 
Sample Dictionary 
{1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}
"""


result = {}

for i in range(1, 16):
    result[i] = i*i
print(result)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
#8. Write a Python program to sum all the items in a dictionary.

# %%
d = {'a':1,
    'b':2,
    'c':3,
    'd':4}
result = 0
for i in d.values():
    result = result + i 
print(result)
# Out:
# 10

# %%
#9. Write a Python program to remove a key from a dictionary.

# %%
d = {'a':1,
    'b':2,
    'c':3,
    'd':4}

d.pop('a')
print(d)
# Out:
# {'b': 2, 'c': 3, 'd': 4}

# %%
#10. Write a Python program to map two lists into a dictionary.

# %%
keys = ['name', 'age', 'course']
values = ['sakshi',21,'data science']

result = {}
for i in range(len(keys)):
    result[keys[i]]=values[i]
print(result)
# Out:
# {'name': 'sakshi', 'age': 21, 'course': 'data science'}

# %%
# 11. Write a Python program to sort a given dictionary by key. (Assume keys are of int type)

# %%
x = {1:'a',
    2:'b',
    5:'c',
    7:'d',
    3:'e',
    6:'f',
    4:'g' }

y = dict(sorted(x.items()))
print(y)
# Out:
# {1: 'a', 2: 'b', 3: 'e', 4: 'g', 5: 'c', 6: 'f', 7: 'd'}

# %%
#12. Write a Python program to sort a given dictionary by values. (Assume values are of int type)

# %%
x = {'a':1,
    'b':2,
    'c':9,
    'd':6,
    'e':3,
    'f':5}

y = dict(sorted(x.items(),key = lambda item : item[1]))
print(y)
# Out:
# {'a': 1, 'b': 2, 'e': 3, 'f': 5, 'd': 6, 'c': 9}

# %%
# 13. Write a Python program to get the maximum and minimum values of a dictionary.

# %%
data = {'a':20,
       'b': 50,
       'c':10,
       'd':65}
y = max(data)
print(y)
# Out:
# d

# %%
x = min(data)
print(x)
# Out:
# a

# %%
# 14. Write a Python program to remove duplicates values from the dictionary.

# %%
data1 = {'a':2,
        'b':4,
        'c':4,
        'd':1,
        'e':0}
result = {}

for i, j in data1.items():
    if j not in result.values():
        result[i]=j
        
print(result)
# Out:
# {'a': 2, 'b': 4, 'd': 1, 'e': 0}

# %%
#15. Write a Python program to check if a dictionary is empty or not.

# %%
xx = {'a':1,
     'b':2}

if not xx:
    print("this dictionary is empty")
else:
    print("this dictionary is not empty")
# Out:
# this dictionary is not empty

# %%
'''16. Write a Python program to combine two dictionary by adding values for common keys. 
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
Sample output: Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})'''


d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}

# %%
result = {}

for i in d1:
    result[i] = d1[i]
    
for j in d2:
    if j in result:
        result[j] = result[j] + d2[j]
    else:
        result[j] = d2[j]
        
print(result)
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}

# %%
'''17. Write a Python program to print all distinct values from a list of dictionaries . 
Sample Data : [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
Expected Output : Unique Values: {'S005', 'S002', 'S007', 'S001', 'S009'}'''

# %%
Data = [
    {"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"}, {"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}
]
    
unique = set()

for i in data:
    for value in i.values():
        unique.add(value)
        
print(unique)
# Out:
# {'S002', 'S005', 'S001', 'S007', 'S009'}

# %%
'''18. Write a Python program to create and display all combinations of letters, selecting each letter from a different key in a dictionary. 
Sample data : {'1':['a','b'], '2':['c','d']}
Expected Output: 
ac
ad
bc
bd'''

# %%
data : {'1':['a','b'], 
        '2':['c','d']
       }
    
for i in data['1']:
    for j in data['2']:
        print(i + j)
# Out:
# ac
# ad
# bc
# bd

# %%
# 19. Write a Python program to find the highest 3 values of corresponding keys in a dictionary. 

data = {
    'a': 10,
    'b': 40,
    'c': 30,
    'd': 50,
    'e': 20
}

result = sorted(data.items(),key = lambda item : item[1],reverse = True)
result1 = dict(result[:3])

print(result1)
# Out:
# {'d': 50, 'b': 40, 'c': 30}

# %%
'''20. Write a Python program to create a dictionary from a string. 
Note: Track the count of the letters from the string.
Sample string : 'shabib shaikh'
Expected output: {'s': 2, 'h': 2, 'a': 2, 'b': 2, 'i': 2, 'k': 1, ' ': 1}'''

# %%
string='shabib shaikh'
    
result = {}

for i in string:
    if i in result:
        result[i] = result[i] + 1
    else:
        result[i] = 1
print(result)
# Out:
# {'s': 2, 'h': 3, 'a': 2, 'b': 2, 'i': 2, ' ': 1, 'k': 1}

# %%
# 21. Write a Python program to sort a list alphabetically in a dictionary. 

x = {'a':1,
    'e':2,
    'b':9,
    'd':6,
    'c':3,
    'f':5}
s = dict(sorted(x.items()))
print(s)
# Out:
# {'a': 1, 'b': 9, 'c': 3, 'd': 6, 'e': 2, 'f': 5}

# %%
'''22. Write a Python program to get the top three items in a shop. 
Sample data: {'item1': 45.50, 'item2':35, 'item3': 41.30, 'item4':55, 'item5': 24}
Expected Output: 
item4 55
item1 45.5
item3 41.3'''

# %%
sample_data = {'item1': 45.50, 'item2':35, 'item3': 41.30, 'item4':55, 'item5': 24}

s = dict(sorted(sample_data.items(),key = lambda item : item[1], reverse = True))
print(s)
# Out:
# {'item4': 55, 'item1': 45.5, 'item3': 41.3, 'item2': 35, 'item5': 24}

# %%
#23. Write a Python program to get the key, value and item in a dictionary.

# %%
x = {'a':1,
    'e':2,
    'b':9,
    'd':6,
    'c':3,
    'f':5}

for i, j in x.items():
    print(i,j)
# Out:
# a 1
# e 2
# b 9
# d 6
# c 3
# f 5

# %%
# 24. Write a Python program to print a dictionary line by line.

# %%
x = {'a':1,
    'e':2,
    'b':9,
    'd':6,
    'c':3,
    'f':5}
for i, j in x.items():
    print(i, ':', j)
# Out:
# a : 1
# e : 2
# b : 9
# d : 6
# c : 3
# f : 5

# %%
# 25. Write a Python program to count the number of items in a dictionary value that is a list.

# %%
x = {'a':[1,2,3],
    'e':[2,4,9],
    'b':[9],
    'd':[6,1],
    'c':[3,0],
    'f':[5]}

stored = 0
for i in x.values():
    stored = stored + len(i)
print(stored)
# Out:
# 12

# %%
'''
26. Write a Python program to create a dictionary from two lists. 
Sample lists: ['Class-V', 'Class-VI', 'Class-VII', 'Class-VIII'], [1, 2, 2, 3]
Expected Output: defaultdict(<class 'set'>, {'Class-V': {1}, 'Class-VI': {2}, 'Class-VII': {2}, 'Class-VIII': {3}})'''

# %%
samplelists1 = ['Class-V', 'Class-VI', 'Class-VII', 'Class-VIII']
samplelists2 = [1, 2, 2, 3]    

result = {}
for i in range(len(samplelists1)):
    result[samplelists1[i]] = samplelists2[i]
print(result)
# Out:
# {'Class-V': 1, 'Class-VI': 2, 'Class-VII': 2, 'Class-VIII': 3}

# %%
'''27. Write a Python program to match key values in two dictionaries. 
Sample dictionary: {'key1': 1, 'key2': 3, 'key3': 2}, {'key1': 1, 'key2': 2}
Expected output: key1: 1 is present in both x and y'''

# %%
dictt = {'key1': 1, 'key2': 3, 'key3': 2}
dictt2 = {'key1': 1, 'key2': 2}

a = input("enter the key: ")

if a in  dictt and a in dictt2:
    print(a, "is present both dictionaries. ")
elif a in  dictt:
    print(a, "is only present in dictt. ")
elif a in  dictt2:
    print(a, "is present only dictt2. ")
else:
    print(a, "it is not in both dictionaries. ")
# Out:
# enter the key: key3
# key3 is only present in dictt.

# %%
'''28. Write a Python program to create a dictionary of keys x, y, and z where each key has as value a list from 11-20, 21-30, and 31-40 respectively. Access the fifth value of each key from the dictionary. 
{'x': [11, 12, 13, 14, 15, 16, 17, 18, 19],
'y': [21, 22, 23, 24, 25, 26, 27, 28, 29],
'z': [31, 32, 33, 34, 35, 36, 37, 38, 39]}
15
25
35
x has value [11, 12, 13, 14, 15, 16, 17, 18, 19]
y has value [21, 22, 23, 24, 25, 26, 27, 28, 29]
z has value [31, 32, 33, 34, 35, 36, 37, 38, 39]'''

# %%
data = {
    'x' : list(range(11,20)),
    'y' : list(range(21,30)),
    'z' : list(range(31,40))
}

print(data)

print(data['x'][4])
print(data['y'][4])
print(data['z'][4])

for i, j in data.items():
    print(i, "has value", j)
# Out:
# {'x': [11, 12, 13, 14, 15, 16, 17, 18, 19], 'y': [21, 22, 23, 24, 25, 26, 27, 28, 29], 'z': [31, 32, 33, 34, 35, 36, 37, 38, 39]}
# 15
# 25
# 35
# x has value [11, 12, 13, 14, 15, 16, 17, 18, 19]
# y has value [21, 22, 23, 24, 25, 26, 27, 28, 29]
# z has value [31, 32, 33, 34, 35, 36, 37, 38, 39]

# %%
'''29. Write a Python program to drop empty items from a given dictionary. 
Original Dictionary:
{'c1': 'Red', 'c2': 'Green', 'c3': None}
New Dictionary after dropping empty items:
{'c1': 'Red', 'c2': 'Green'}'''

# %%
a = {'c1': 'Red', 'c2': 'Green', 'c3': None}
result = {}

for i,j in a.items():
    if j is not None:
        result[i] = j
print(a)
print(result)
# Out:
# {'c1': 'Red', 'c2': 'Green', 'c3': None}
# {'c1': 'Red', 'c2': 'Green'}

# %%
'''30. Write a Python program to filter a dictionary based on values. 
Original Dictionary:
{'Cierra Vega': 175, 'Alden Cantrell': 180, 'Kierra Gentry': 165, 'Pierre Cox': 190}
Marks greater than 170:
{'Cierra Vega': 175, 'Alden Cantrell': 180, 'Pierre Cox': 190}'''


org = {'Cierra Vega': 175, 'Alden Cantrell': 180, 'Kierra Gentry': 165, 'Pierre Cox': 190}
org_up = {}

for i, j in org.items():
    if j > 170:
        org_up[i]=j
print(org_up)
# Out:
# {'Cierra Vega': 175, 'Alden Cantrell': 180, 'Pierre Cox': 190}

# %% [raw]
# 31. Write a Python program to convert more than one list to a nested dictionary.
# Original strings:
# ['S001', 'S002', 'S003', 'S004']
# ['Sonu Khan', 'Chikoo Singh', 'Bhola Thakur', 'Pinki Kumari']
# [85, 98, 89, 92]
# Nested dictionary:
# [{'S001': {'Sonu Khan': 85}}, {'S002': {'Chikoo Singh': 98}}, {'S003': {'Bhola Thakur': 89}}, {'S004': {'Pinki Kumari': 92}}]

# %%
'''31. Write a Python program to convert more than one list to a nested dictionary. 
Original strings:
['S001', 'S002', 'S003', 'S004']
['Sonu Khan', 'Chikoo Singh', 'Bhola Thakur', 'Pinki Kumari']
[85, 98, 89, 92]
Nested dictionary:
[{'S001': {'Sonu Khan': 85}}, {'S002': {'Chikoo Singh': 98}}, {'S003': {'Bhola Thakur': 89}}, {'S004': {'Pinki Kumari': 92}}]

'''

# %%
data = ['S001', 'S002', 'S003', 'S004']
data1 = ['Sonu Khan', 'Chikoo Singh', 'Bhola Thakur', 'Pinki Kumari']
data2 = [85, 98, 89, 92]

result = []

for i in range(len(data)):
    result.append({data[i]:{data1[i]: data2[i]}})
    
print(result)
# Out:
# [{'S001': {'Sonu Khan': 85}}, {'S002': {'Chikoo Singh': 98}}, {'S003': {'Bhola Thakur': 89}}, {'S004': {'Pinki Kumari': 92}}]

# %%
'''32. Write a Python program to filter the height and width of students, which are stored in a dictionary. 
Original Dictionary:
{'Chinki Vinky': (6.2, 70), 'Aloo Paloo': (5.9, 65), 'Golu Molu': (6.0, 68), 'Sonu Monu': (5.8, 66)}
Height > 6ft and Weight> 70kg:
{'Chinki Vinki': (6.2, 70)}'''

# %%
student = {'Chinki Vinky': (6.2, 70), 'Aloo Paloo': (5.9, 65), 'Golu Molu': (6.0, 68), 'Sonu Monu': (5.8, 66)}
result = {}
for key,(h,w) in student.items():
    if h>6 and w>=70:
        result[key] = (h,w)
print(result)
# Out:
# {'Chinki Vinky': (6.2, 70)}

# %%
'''33. Write a Python program to verify that all values in a dictionary are the same. 
Original Dictionary:
{'Samosa Pav': 12, 'Aloo Paratha': 12, 'Gobi Manchurian': 12, 'Pani Puri': 12}
Check all are 12 in the dictionary.
True
Check all are 10 in the dictionary.
False
'''

# %%
food = {'Samosa Pav': 12, 'Aloo Paratha': 12, 'Gobi Manchurian': 12, 'Pani Puri': 12}

value = int(input("enter the value : "))

result = True
for i in food.values():
    if i!= value:
        result = False
        break
print(result)
# Out:
# enter the value : 10
# False

# %%
'''34. Write a Python program to create a dictionary grouping a sequence of key-value pairs into a dictionary of lists. 
Original list:
[('yellow', 1), ('blue', 2), ('yellow', 3), ('blue', 4), ('red', 1)]
Grouping a sequence of key-value pairs into a dictionary of lists:
{'yellow': [1, 3], 'blue': [2, 4], 'red': [1]}'''

# %%
d1 = [('yellow', 1), ('blue', 2), ('yellow', 3), ('blue', 4), ('red', 1)]

result = {}
for i,j in d1:
    if i in result:
        result[i].append(j)
    else:
        result[i] = [j]
print(result)
# Out:
# {'yellow': [1, 3], 'blue': [2, 4], 'red': [1]}

# %%
'''35. Write a Python program to split a given dictionary of lists into lists of dictionaries. 
Original dictionary of lists:
{'Science': [88, 89, 62, 95], 'Language': [77, 78, 84, 80]}
Split said dictionary of lists into list of dictionaries:
[{'Science': 88, 'Language': 77}, {'Science': 89, 'Language': 78}, {'Science': 62, 'Language': 84}, {'Science': 95, 'Language': 80}]'''

# %%
org = {'Science': [88, 89, 62, 95], 'Language': [77, 78, 84, 80]}

res = []
for i in range(len(org['Science'])):
    res1 = {}
    for j in org:
        res1[j] = org[j][i]
    res.append(res1)
print(res)
# Out:
# [{'Science': 88, 'Language': 77}, {'Science': 89, 'Language': 78}, {'Science': 62, 'Language': 84}, {'Science': 95, 'Language': 80}]

# %%
'''36. Write a Python program to remove a specified dictionary from a given list. 
Original list of dictionary:
[{'id': '#FF0000', 'color': 'Red'}, {'id': '#800000', 'color': 'Maroon'}, {'id': '#FFFF00', 'color': 'Yellow'}, {'id': '#808000', 'color': 'Olive'}]
Remove id #FF0000 from the said list of dictionary:
[{'id': '#800000', 'color': 'Maroon'}, {'id': '#FFFF00', 'color': 'Yellow'}, {'id': '#808000', 'color': 'Olive'}]
'''

# %%
data = [{'id': '#FF0000', 'color': 'Red'},
        {'id': '#800000', 'color': 'Maroon'}, 
        {'id': '#FFFF00', 'color': 'Yellow'}, 
        {'id': '#808000', 'color': 'Olive'}]
a = []
for i in data:
    if i['id'] != '#FF0000':
        a.append(i)
print(a)
# Out:
# [{'id': '#800000', 'color': 'Maroon'}, {'id': '#FFFF00', 'color': 'Yellow'}, {'id': '#808000', 'color': 'Olive'}]

# %%
'''37. Write a Python program to convert string values of a given dictionary into integer/float datatypes. 
Original list:
[{'x': '10', 'y': '20', 'z': '30'}, {'p': '40', 'q': '50', 'r': '60'}]
String values of a given dictionary, into integer types:
[{'x': 10, 'y': 20, 'z': 30}, {'p': 40, 'q': 50, 'r': 60}]
Original list:
[{'x': '10.12', 'y': '20.23', 'z': '30'}, {'p': '40.00', 'q': '50.19', 'r': '60.99'}]
String values of a given dictionary, into float types:
[{'x': 10.12, 'y': 20.23, 'z': 30.0}, {'p': 40.0, 'q': 50.19, 'r': 60.99}]
'''

# %%
data = [
    {'x': '10', 'y': '20', 'z': '30'},
    {'p': '40', 'q': '50', 'r': '60'}
]

result = []

for d in data:
    new_dict = {}
    for k, v in d.items():
        new_dict[k] = int(v)
    result.append(new_dict)

print(result)
# Out:
# [{'x': 10, 'y': 20, 'z': 30}, {'p': 40, 'q': 50, 'r': 60}]

# %%
'''38. A Python dictionary contains List as a value. Write a Python program to clear the list values in the said dictionary. 
Original Dictionary:
{'C1': [10, 20, 30], 'C2': [20, 30, 40], 'C3': [12, 34]}
Clear the list values in the said dictionary:
{'C1': [], 'C2': [], 'C3': []}
'''

# %%
data = {'C1': [10, 20, 30], 'C2': [20, 30, 40], 'C3': [12, 34]}

for k in data:
    data[k].clear()

print(data)
# Out:
# {'C1': [], 'C2': [], 'C3': []}

# %%
'''
 39. Write a Python program to extract a list of values from a given list of dictionaries. 
Original Dictionary:
[{'Math': 90, 'Science': 92}, {'Math': 89, 'Science': 94}, {'Math': 92, 'Science': 88}]
Extract a list of values from said list of dictionaries where subject = Science
[92, 94, 88]
Original Dictionary:
[{'Math': 90, 'Science': 92}, {'Math': 89, 'Science': 94}, {'Math': 92, 'Science': 88}]
Extract a list of values from said list of dictionaries where subject = Math
[90, 89, 92]
'''

# %%
data = [
    {'Math': 90, 'Science': 92},
    {'Math': 89, 'Science': 94},
    {'Math': 92, 'Science': 88}
]


science_marks = [d['Science'] for d in data]
print(science_marks)


math_marks = [d['Math'] for d in data]
print(math_marks)
# Out:
# [92, 94, 88]
# [90, 89, 92]

# %%
# 40. Write a Python program to find the length of a dictionary of values.

# %%
data = {'a': 10, 'b': 20, 'c': 30, 'd': 40}

length = len(data)
print("Length of dictionary:", length)
# Out:
# Length of dictionary: 4

# %%
# 41. Write a Python program to get the depth of a dictionary.

# %%
def dict_depth(d):
    if not isinstance(d, dict) or not d:
        return 0
    return 1 + max(dict_depth(v) for v in d.values())

# Example
data = {
    'a': 1,
    'b': {'c': 2},
    'd': {'e': {'f': 3}}
}

print("Depth of dictionary:", dict_depth(data))
# Out:
# Depth of dictionary: 3

# %%
'''42. Write a Python program to convert a dictionary into a list of lists. 
Original Dictionary:
{1: 'red', 2: 'green', 3: 'black', 4: 'white', 5: 'black'}
Convert the said dictionary into a list of lists:
[[1, 'red'], [2, 'green'], [3, 'black'], [4, 'white'], [5, 'black']]
Original Dictionary:
{'1': 'Austin Little', '2': 'Natasha Howard', '3': 'Alfred Mullins', '4': 'Jamie Rowe'}
Convert the said dictionary into a list of lists:
[['1', 'Austin Little'], ['2', 'Natasha Howard'], ['3', 'Alfred Mullins'], ['4', 'Jamie Rowe']]'''

# %%
d = {1: 'red', 2: 'green', 3: 'black', 4: 'white', 5: 'black'}

result = []

for k, v in d.items():
    result.append([k, v])

print(result)
# Out:
# [[1, 'red'], [2, 'green'], [3, 'black'], [4, 'white'], [5, 'black']]

# %%
"""43. Write a Python program to filter even numbers from a dictionary of values. 
Original Dictionary:
{'V': [1, 4, 6, 10], 'VI': [1, 4, 12], 'VII': [1, 3, 8]}
Filter even numbers from said dictionary values:
{'V': [4, 6, 10], 'VI': [4, 12], 'VII': [8]}
Original Dictionary:
{'V': [1, 3, 5], 'VI': [1, 5], 'VII': [2, 7, 9]}
Filter even numbers from said dictionary values:
{'V': [], 'VI': [], 'VII': [2]}
"""

# %%
data = {'V': [1, 4, 6, 10],
        'VI': [1, 4, 12],
        'VII': [1, 3, 8]}

result = {}

for key, values in data.items():
    even_list = []
    for num in values:
        if num % 2 == 0:
            even_list.append(num)
    result[key] = even_list

print(result)
# Out:
# {'V': [4, 6, 10], 'VI': [4, 12], 'VII': [8]}

# %%
"""44. Write a Python program to find the specified number of maximum values in a given dictionary. 
Original Dictionary:
{'a': 5, 'b': 14, 'c': 32, 'd': 35, 'e': 24, 'f': 100, 'g': 57, 'h': 8, 'i': 100}
1 maximum value(s) in the said dictionary:
['f']
2 maximum value(s) in the said dictionary:
['f', 'i']
5 maximum value(s) in the said dictionary:
['f', 'i', 'g', 'd', 'c']
"""

# %%
data = {'a': 5, 'b': 14, 'c': 32, 'd': 35,
        'e': 24, 'f': 100, 'g': 57,
        'h': 8, 'i': 100}

n = int(input("Enter number of maximum values: "))

# convert dictionary items into list
items = list(data.items())

# sort list based on values (descending)
items.sort(key=lambda x: x[1], reverse=True)

result = []

for i in range(n):
    result.append(items[i][0])

print(result)
# Out:
# Enter number of maximum values: 1
# ['f']

# %%
'''45. Write a Python program to find the shortest list of values for the keys in a given dictionary. 
Original Dictionary: {'V': [10, 12], 'VI': [10], 'VII': [10, 20, 30, 40], 'VIII': [20], 'IX': [10, 30, 50, 70], 
'X': [80]} Shortest list of values with the keys of the said dictionary: ['VI', 'VIII', 'X']'''

# %%
data = {'V': [10, 12],
        'VI': [10],
        'VII': [10, 20, 30, 40],
        'VIII': [20],
        'IX': [10, 30, 50, 70],
        'X': [80]}


min_len = None

for values in data.values():
    if min_len is None or len(values) < min_len:
        min_len = len(values)


result = []

for key, values in data.items():
    if len(values) == min_len:
        result.append(key)

print(result)
# Out:
# ['VI', 'VIII', 'X']
